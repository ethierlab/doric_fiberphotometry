# %% [markdown]
# # 1-Import Data

# %%
# import numpy as np
# import pandas as pd
# from ipywidgets import GridBox, Layout

import fileselector as fs
from importlib import reload
reload(fs)
fs.load_dependencies()
# Usage
# Replace '/your/start/directory/' with your actual start directory
Path='/home/coder/project/doric_fiberphotometry/Data/stim'
file_selector = fs.FileSelector(Path)
# file_name = file_selector.get_selected_file()
# Out:
# Dropdown(description='Select File:', options=('Select a file', '313_NAc_stim20Hz_BL80mA_Apr25_0000_140523915_i…
# Selected file: /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete.doric
# loading dataset .....
# GridBox(children=(Dropdown(description='Isos:', index=5, layout=Layout(height='100px', width='100%'), options=…
# Button(description='Load Data', layout=Layout(display='none'), style=ButtonStyle())
# Datasets loaded.

# %%
## After selecting datasets, the respective info will be displayed.
## Then, click "Load Data" button to load the datasets.
isos_df = file_selector.get_isos_df()
grabda_df = file_selector.get_grabda_df()
event_df = file_selector.get_event_df()

import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

import dataexplorer as de
from importlib import reload
try:
    import ipympl
    print("ipympl is installed. You can proceed with %matplotlib ipympl.")
    # %matplotlib widget
except ImportError:
    print("ipympl is not installed. Please run !pip install ipympl.")
    # !pip install ipympl
    # %matplotlib widget


reload(de)

de.plot_and_save_seperated(isos_df, grabda_df, event_df,file_selector)

de.plot_and_save(isos_df,grabda_df,event_df,file_selector)
# Out:
# ipympl is installed. You can proceed with %matplotlib ipympl.
# Figure saved as /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Figs//raw_data_seperated.png
# Figure saved as /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Figs//raw_data_merged.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Stim Events

# %%
import dataexplorer as de
from importlib import reload

reload(de)

rising_edge_df = de.find_rising_edges(event_df)

classified_events_df = de.classify_events(rising_edge_df,Event_type='Stim')
print(classified_events_df.head())
print("Event Number: ",len(classified_events_df))
# Out:
# stim
#       Time         Type  Sample_Number
# 0   5.0000  Stim 20.0Hz        50000.0
# 1  15.4999  Stim 20.0Hz       154999.0
# 2  25.9999  Stim 20.0Hz       259999.0
# 3  36.4999  Stim 20.0Hz       364999.0
# 4  46.9999  Stim 20.0Hz       469999.0
# Event Number:  9

# %% [markdown]
# # Data Prepration

# %% [markdown]
# ##  Use function get_zdFF to calculate z-dF/F

# %% [markdown]
# Download photometry_functions.py file from [here](https://github.com/katemartian/Photometry_data_processing "source").
#
# please cite Jove paper:
#
# __Martianova, E., Aronson, S., Proulx, C.D.__ [Multi-Fiber Photometry to Record Neural Activity in Freely Moving Animal.](https://www.jove.com/video/60278/multi-fiber-photometry-to-record-neural-activity-freely-moving). _J. Vis. Exp._ (152), e60278, doi:10.3791/60278 (2019).
#
# [refrence](https://colab.research.google.com/github/katemartian/Photometry_data_processing/blob/master/Photometry_data_processing.ipynb#scrollTo=Lak9o-Hn3QQW)

# %%
from importlib import reload
import photometry_functions as pf
reload(pf)
# Usage
def save_signal(zdff):
    global signal_df 
    signal_df = zdff
    
    print(signal_df.head())
analysis = pf.PhotometryAnalysis(isos_df,grabda_df,save_signal)
# Out:
# IntText(value=10, description='Cutoff Freq:')
# IntText(value=0, description='remove(ms):')
# FloatLogSlider(value=500000000000.0, description='lambd:', max=16.0, min=5.0)
# IntText(value=10, description='porder:')
# IntText(value=50, description='itermax:')
# Button(description='Run Function', style=ButtonStyle())
# Output()

# %% [markdown]
# # PSTH Prepration

# %% [markdown]
# ## Cut and Center the Data

# %%
import photometry_functions as pf
from importlib import reload

reload(pf)

# Example usage:
time_window = (-4, 10)  # For example, 2 seconds before and after the event
event_type = "All"  # Use "All" to process all events, or specify a particular type like 'Init'
centralized_signals_df = pf.cut_and_center_signals_modified(signal_df, classified_events_df, time_window, event_type)
print(centralized_signals_df.head())
# Out:
#              Time      Data
# Event Row
# 1     90  -3.9998  1.279575
#       91  -3.9898  1.309478
#       92  -3.9798  1.342967
#       93  -3.9698  1.369063
#       94  -3.9598  1.382907

# %% [markdown]
# ## Plot Dataset

# %% [markdown]
# ### Plot all Signals

# %%
import os
# Plot All signals
y_min = -2
y_max = 4

import photometry_functions as pf
from importlib import reload

reload(pf)
# Example usage:
fig = plt
pf.plot_cut_signals(centralized_signals_df,y_min,y_max)
# plot_cut_signals(filtered_signal_df)
filename = file_selector.file_path.split('.')[0]+'/Figs/'+'/all_Events.png'

directory = os.path.dirname(filename)
if not os.path.exists(directory):
    os.makedirs(directory)

fig.savefig(filename, dpi=300, bbox_inches='tight')
print(f"Figure saved as {filename}")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Figure saved as /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Figs//all_Events.png

# %% [markdown]
# ### Plot Signals seperatly

# %%
import photometry_functions as pf
from importlib import reload

reload(pf)
# Example usage
pf.plot_cut_signals_seperated(centralized_signals_df,y_min,y_max)

fig = plt
filename = file_selector.file_path.split('.')[0]+'/Figs/'+'/Separeted_Events.png'

directory = os.path.dirname(filename)
if not os.path.exists(directory):
    os.makedirs(directory)

fig.savefig(filename, dpi=300, bbox_inches='tight')
print(f"Figure saved as {filename}")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Figure saved as /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Figs//Separeted_Events.png

# %% [markdown]
# ### Plot and Select Signals for PSTH

# %%
import photometry_functions as pf
from importlib import reload

reload(pf)

# Example usage:

def handle_filtered_data(df,event_type):
    # Handle the filtered DataFrame here, e.g., save it to a global variable or process it further
    global filtered_signal_df
    filtered_signal_df = df
    print(filtered_signal_df.head())

    fig = plt
    filename = file_selector.file_path.split('.')[0]+'/Figs/'+'/Selected_Stim_Events.png'

    directory = os.path.dirname(filename)
    if not os.path.exists(directory):
        os.makedirs(directory)

    fig.savefig(filename, dpi=300, bbox_inches='tight')
    print(f"Figure saved as {filename}")


    

# Example usage:
explorer = pf.SignalExplorer(centralized_signals_df,'Stim', save_callback=handle_filtered_data)
# This will display the widgets and allow interaction
# Out:
# GridspecLayout(children=(Checkbox(value=False, description='Select All', layout=Layout(grid_area='widget001'))…
# Button(description='Apply Selection', style=ButtonStyle())
# Output()
# Filtered data is ready.
#              Time      Data
# Event Row
# 1     90  -3.9998  1.279575
#       91  -3.9898  1.309478
#       92  -3.9798  1.342967
#       93  -3.9698  1.369063
#       94  -3.9598  1.382907
# Figure saved as /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Figs//Selected_Stim_Events.png

# %% [markdown]
# ## Normalization

# %%
import photometry_functions as pf
from importlib import reload

reload(pf)

# Example usage:
# Assuming 'Data' is the column in filtered_signal_df that you want to normalize
normalized_signal_df = pf.normalize_signal(filtered_signal_df, column='Data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/coder/project/doric_fiberphotometry/Stim-doric-psth.ipynb Cell 21 line 8
#       <a href='vscode-notebook-cell://localhost:1988/home/coder/project/doric_fiberphotometry/Stim-doric-psth.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> reload(pf)
#       <a href='vscode-notebook-cell://localhost:1988/home/coder/project/doric_fiberphotometry/Stim-doric-psth.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> # Example usage:
#       <a href='vscode-notebook-cell://localhost:1988/home/coder/project/doric_fiberphotometry/Stim-doric-psth.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> # Assuming 'Data' is the column in filtered_signal_df that you want to normalize
# ----> <a href='vscode-notebook-cell://localhost:1988/home/coder/project/doric_fiberphotometry/Stim-doric-psth.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> normalized_signal_df = pf.normalize_signal(filtered_signal_df, column='Data')
#
# NameError: name 'filtered_signal_df' is not defined

# %% [markdown]
# # This will normalize between -1 and 1 (not recomended to run it will incrupt the AUC)

# %%
max=normalized_signal_df['Data'].max()
min=normalized_signal_df['Data'].min()
diff = max - min

new_df=(2*(normalized_signal_df['Data'] - min)/diff)-1
print(new_df.max())
print(new_df.min())
normalized_signal_df['Data']= new_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/coder/project/doric_fiberphotometry/Stim-doric-psth.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell://localhost:1988/home/coder/project/doric_fiberphotometry/Stim-doric-psth.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> max=normalized_signal_df['Data'].max()
#       <a href='vscode-notebook-cell://localhost:1988/home/coder/project/doric_fiberphotometry/Stim-doric-psth.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> min=normalized_signal_df['Data'].min()
#       <a href='vscode-notebook-cell://localhost:1988/home/coder/project/doric_fiberphotometry/Stim-doric-psth.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> diff = max - min
#
# NameError: name 'normalized_signal_df' is not defined

# %% [markdown]
# # Analyze Resaults

# %% [markdown]
# ## PSTH

# %%
import photometry_functions as pf
import os
from importlib import reload

reload(pf)

PSTH_df=pf.create_psth_with_min_max(normalized_signal_df)

PSTH_df_std = pf.create_psth_with_std(normalized_signal_df)

PSTH_df_ci = pf.create_psth_with_ci(normalized_signal_df)

fig, axs = plt.subplots(3, 1, figsize=(12, 18))

pf.plot_psth(PSTH_df_ci, -2, 4,'green','stim',pos=axs[2])
pf.plot_psth(PSTH_df, -2, 4,'green','stim',pos=axs[1])
pf.plot_psth(PSTH_df_std, -2, 4,'green','stim',pos=axs[0])

plt.tight_layout()

plt.show()

filename = file_selector.file_path.split('.')[0]+'/Figs/'+'PSTH.png'


directory = os.path.dirname(filename)
if not os.path.exists(directory):
    os.makedirs(directory)

fig.savefig(filename, dpi=300, bbox_inches='tight')
print(f"Figure saved as {filename}")
# Out:
# [-6. -4. -2.  0.  2.  4.  6.  8. 10. 12.]
# [-6.   -4.   -2.    0.    0.51  2.    4.    6.    8.   10.   12.  ]
# [-6.   -4.   -2.    0.    0.51  2.    4.    6.    8.   10.   12.  ]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Figure saved as /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Figs/PSTH.png

# %% [markdown]
# ## HeatMap

# %%
import photometry_functions as pf
import os
from importlib import reload

reload(pf)
# fig = plt
# pf.heatmap_plot(filtered_signal_df)
pf.heatmap_plot(normalized_signal_df)

filename = file_selector.file_path.split('.')[0]+'/Figs/'+'/Heatmap.png'
directory = os.path.dirname(filename)
if not os.path.exists(directory):
    os.makedirs(directory)

plt.savefig(filename, dpi=300, bbox_inches='tight')
print(f"Figure saved as {filename}")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Figure saved as /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Figs//Heatmap.png

# %% [markdown]
# ### Area Under Curves

# %%
import photometry_functions as pf
from importlib import reload

reload(pf)

# Example usage
plt.figure(figsize=(12, 6))

pf.plot_psth_auc(PSTH_df_std,-2, 3.5,'green','Stim')
plt.show()
filename = file_selector.file_path.split('.')[0]+'/Figs/'+'AUC.png'

directory = os.path.dirname(filename)
if not os.path.exists(directory):
    os.makedirs(directory)
plt.savefig(filename, dpi=300, bbox_inches='tight')
print(f"Figure saved as {filename}")

pf.plot_auc_bars(PSTH_df_std,-0.4, 0.4)
filename = file_selector.file_path.split('.')[0]+'/Figs/'+'AUC_Bars.png'

directory = os.path.dirname(filename)
if not os.path.exists(directory):
    os.makedirs(directory)
plt.savefig(filename, dpi=300, bbox_inches='tight')
print(f"Figure saved as {filename}")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Figure saved as /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Figs/AUC.png
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Figure saved as /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Figs/AUC_Bars.png
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
import datetime

def save_dataframes_to_csv():
    # Fetch the current datetime to append to file names to avoid overwriting
    now = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = file_selector.file_path.split('.')[0]+'/Data/'+'test.csv"'
    directory = os.path.dirname(filename)
    if not os.path.exists(directory):
        os.makedirs(directory)
    # Loop through all global variables
    for var_name, value in list(globals().items()):
        # Check if the value is an instance of pd.DataFrame
        if isinstance(value, pd.DataFrame):
            # Construct filename with a timestamp to prevent overwriting
            file = f"{var_name}_{now}.csv"
            filename = file_selector.file_path.split('.')[0]+'/Data/'+file

            # Save the DataFrame to a CSV file
            value.to_csv(filename, index=False)
            print(f"Saved {filename}")


# Call the function to save all DataFrames
save_dataframes_to_csv()
# Out:
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/isos_df_20240430_223322.csv
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/grabda_df_20240430_223322.csv
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/event_df_20240430_223322.csv
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/rising_edge_df_20240430_223322.csv
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/classified_events_df_20240430_223322.csv
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/signal_df_20240430_223322.csv
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/centralized_signals_df_20240430_223322.csv
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/filtered_signal_df_20240430_223322.csv
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/normalized_signal_df_20240430_223322.csv
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/PSTH_df_20240430_223322.csv
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/PSTH_df_std_20240430_223322.csv
# Saved /home/coder/project/doric_fiberphotometry/Data/stim/315_NAc_stim20Hz_BL80mA_Apr25_0000_141012914_incomplete/Data/PSTH_df_ci_20240430_223322.csv
